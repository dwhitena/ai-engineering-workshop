# %%
! pip install huggingface_hub trl transformers accelerate peft datasets bitsandbytes einops scipy py7zr predictionguard
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.16.4)
# Requirement already satisfied: trl in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.34.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.14.5)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.41.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.3)
# Requirement already satisfied: py7zr in /usr/local/lib/python3.10/dist-packages (0.20.6)
# Collecting predictionguard
#   Downloading predictionguard-1.4.2-py2.py3-none-any.whl (7.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl) (2.0.1+cu118)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from trl) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: texttable in /usr/local/lib/python3.10/dist-packages (from py7zr) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from py7zr) (3.19.0)
# Requirement already satisfied: pyzstd>=0.14.4 in /usr/local/lib/python3.10/dist-packages (from py7zr) (0.15.9)
# Requirement already satisfied: pyppmd<1.1.0,>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from py7zr) (1.0.0)
# Requirement already satisfied: pybcj>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from py7zr) (1.0.1)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from py7zr) (0.2.3)
# Requirement already satisfied: brotli>=1.0.9 in /usr/local/lib/python3.10/dist-packages (from py7zr) (1.1.0)
# Requirement already satisfied: inflate64>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from py7zr) (0.3.1)
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.10/dist-packages (from predictionguard) (0.9.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4.0->trl) (3.27.5)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4.0->trl) (17.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Installing collected packages: predictionguard
# Successfully installed predictionguard-1.4.2

# %%
import os
from random import randrange

import predictionguard as pg
from datasets import load_dataset
import torch
from transformers import AutoModelForCausalLM, BitsAndBytesConfig, AutoTokenizer, TrainingArguments
from peft import LoraConfig, PeftModel
from trl import SFTTrainer
from getpass import getpass

# %%
hf_token = getpass('Enter your Hugging Face token: ')
# Out:
# Enter your Hugging Face token: ··········

# %% [markdown]
# # Preparing the dataset

# %%
dataset = load_dataset("samsum")
# Out:
# Downloading builder script:   0%|          | 0.00/3.36k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.04k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.94M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/14732 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/819 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/818 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 14732
#     })
#     test: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 819
#     })
#     validation: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 818
#     })
# })

# %%
dataset['train'][0]
# Out:
# {'id': '13818513',
#  'dialogue': "Amanda: I baked  cookies. Do you want some?\r\nJerry: Sure!\r\nAmanda: I'll bring you tomorrow :-)",
#  'summary': 'Amanda baked cookies and will bring Jerry some tomorrow.'}

# %%
def dialogue_to_prompt(dialogue):
  return """### Instruction:
Summarize the conversation in the below input. Use a single short sentence or statement.

### Input:
{dialogue}

### Response:
""".format(dialogue=dialogue)

#for split in ['train', 'test', 'validation']:
dataset = dataset.map(lambda x: {"input": dialogue_to_prompt(x['dialogue'])})
dataset = dataset.rename_column("summary", "output")
# Out:
# Map:   0%|          | 0/14732 [00:00<?, ? examples/s]
# Map:   0%|          | 0/819 [00:00<?, ? examples/s]
# Map:   0%|          | 0/818 [00:00<?, ? examples/s]

# %%
dataset['train'][0]
# Out:
# {'id': '13818513',
#  'dialogue': "Amanda: I baked  cookies. Do you want some?\r\nJerry: Sure!\r\nAmanda: I'll bring you tomorrow :-)",
#  'output': 'Amanda baked cookies and will bring Jerry some tomorrow.',
#  'input': "### Instruction:\nSummarize the conversation in the below input. Use a single short sentence or statement.\n\n### Input:\nAmanda: I baked  cookies. Do you want some?\r\nJerry: Sure!\r\nAmanda: I'll bring you tomorrow :-)\n\n### Response:\n"}

# %%
print(dataset['train'][0]['input'])
# Out:
# ### Instruction:
# Summarize the conversation in the below input. Use a single short sentence or statement.
#
# ### Input:
# Amanda: I baked  cookies. Do you want some?
# Jerry: Sure!
# Amanda: I'll bring you tomorrow :-)
#
# ### Response:

# %% [markdown]
# # Load a model to fine-tune

# %%
base_model_name = "meta-llama/Llama-2-7b-hf"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=True,
    token=hf_token
)
base_model.config.use_cache = False

# More info: https://github.com/huggingface/transformers/pull/24906
base_model.config.pretraining_tp = 1

tokenizer = AutoTokenizer.from_pretrained(
    base_model_name,
    trust_remote_code=True,
    token=hf_token
)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %% [markdown]
# # Training

# %%
output_dir = "./Llama-2-7b-hf-samsum"

training_args = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    learning_rate=2e-4,
    logging_steps=50,
    max_steps=1000,
    logging_dir="./logs",        # Directory for storing logs
    save_strategy="steps",       # Save the model checkpoint every logging step
    save_steps=50,                # Save checkpoints every 50 steps
    evaluation_strategy="steps", # Evaluate the model every logging step
    eval_steps=50,               # Evaluate and save checkpoints every 50 steps
    do_eval=True                 # Perform evaluation at the end of training
)

# %%
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
)

# %%
def formatting_func(example):
    text = f"{example['input']}{example['output']}"
    return [text]

max_seq_length = 512
trainer = SFTTrainer(
    model=base_model,
    train_dataset=dataset['train'],
    eval_dataset=dataset['test'],
    peft_config=peft_config,
    formatting_func=formatting_func,
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_args,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:122: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/14732 [00:00<?, ? examples/s]
# Map:   0%|          | 0/819 [00:00<?, ? examples/s]

# %%
# pass in resume_from_checkpoint=True to resume from a checkpoint
trainer.train()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1000' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 5:21:14, Epoch 1000/1000]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.109600</td>
#       <td>2.597891</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.028800</td>
#       <td>4.067489</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.005900</td>
#       <td>4.188659</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.005600</td>
#       <td>4.242595</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.005500</td>
#       <td>4.262155</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.005500</td>
#       <td>4.301471</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.005500</td>
#       <td>4.315260</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.005400</td>
#       <td>4.352552</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.005400</td>
#       <td>4.358501</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.005400</td>
#       <td>4.368029</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.005400</td>
#       <td>4.391252</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.005400</td>
#       <td>4.396448</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.005400</td>
#       <td>4.404401</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.005400</td>
#       <td>4.410138</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.005400</td>
#       <td>4.422347</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.005400</td>
#       <td>4.428251</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.005400</td>
#       <td>4.422659</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.005400</td>
#       <td>4.428437</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.005400</td>
#       <td>4.428613</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.005400</td>
#       <td>4.430209</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1000, training_loss=0.06182192170619965, metrics={'train_runtime': 19297.1695, 'train_samples_per_second': 0.829, 'train_steps_per_second': 0.052, 'total_flos': 3.0601258205184e+17, 'train_loss': 0.06182192170619965, 'epoch': 1000.0})

# %% [markdown]
# # Save the model

# %%
! zip -r llama-samsum.zip Llama-2-7b-hf-samsum
# Out:
#   adding: Llama-2-7b-hf-samsum/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/trainer_state.json (deflated 79%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-350/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/trainer_state.json (deflated 84%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-650/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/trainer_state.json (deflated 64%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-100/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/trainer_state.json (deflated 73%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-200/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/trainer_state.json (deflated 77%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-300/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/trainer_state.json (deflated 83%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-550/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/scheduler.pt (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/trainer_state.json (deflated 85%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-850/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/trainer_state.json (deflated 83%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-600/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/trainer_state.json (deflated 81%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-450/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/scheduler.pt (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/trainer_state.json (deflated 86%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-900/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/scheduler.pt (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/trainer_state.json (deflated 86%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-950/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/trainer_state.json (deflated 85%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-750/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/trainer_state.json (deflated 69%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-150/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/trainer_state.json (deflated 85%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-800/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/scheduler.pt (deflated 50%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/trainer_state.json (deflated 86%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-1000/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/trainer_state.json (deflated 84%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-700/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/trainer_state.json (deflated 80%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-400/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/trainer_state.json (deflated 76%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-250/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/trainer_state.json (deflated 82%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-500/adapter_model.bin (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/ (stored 0%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/training_args.bin (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/scheduler.pt (deflated 49%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/tokenizer.json (deflated 74%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/special_tokens_map.json (deflated 48%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/rng_state.pth (deflated 28%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/adapter_config.json (deflated 43%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/optimizer.pt (deflated 8%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/README.md (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/trainer_state.json (deflated 57%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/tokenizer_config.json (deflated 67%)
#   adding: Llama-2-7b-hf-samsum/checkpoint-50/adapter_model.bin (deflated 8%)

# %%
! cp llama-samsum.zip /content/drive/MyDrive/llama-samsum.zip

# %% [markdown]
# # Try it out, compare to the base model

# %%
pg_access_token = getpass('Enter your Prediction Guard access token: ')
os.environ['PREDICTIONGUARD_TOKEN'] = pg_access_token
# Out:
# Enter your Prediction Guard access token: ··········

# %%
! cp /content/drive/MyDrive/llama-samsum.zip .
! unzip llama-samsum.zip
# Out:
# Archive:  llama-samsum.zip
#    creating: Llama-2-7b-hf-samsum/
#    creating: Llama-2-7b-hf-samsum/checkpoint-350/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-350/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-650/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-650/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-100/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-100/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-200/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-200/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-300/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-300/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-550/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-550/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-850/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-850/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-600/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-600/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-450/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-450/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-900/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-900/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-950/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-950/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-750/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-750/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-150/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-150/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-800/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-800/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-1000/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-1000/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-700/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-700/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-400/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-400/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-250/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-250/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-500/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-500/adapter_model.bin
#    creating: Llama-2-7b-hf-samsum/checkpoint-50/
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/training_args.bin
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/scheduler.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/tokenizer.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/special_tokens_map.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/rng_state.pth
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/adapter_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/optimizer.pt
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/README.md
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/trainer_state.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/tokenizer_config.json
#   inflating: Llama-2-7b-hf-samsum/checkpoint-50/adapter_model.bin

# %%
base_model_name="meta-llama/Llama-2-7b-hf"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=True,
    token=hf_token
)
tokenizer = AutoTokenizer.from_pretrained(
    base_model_name,
    trust_remote_code=True,
    token=hf_token
)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
model = PeftModel.from_pretrained(base_model, "/content/Llama-2-7b-hf-samsum/checkpoint-1000")

# %%
# select a random test sample
sample = dataset['test'][randrange(len(dataset["test"]))]

# prompt the fine-tuned model
model_input = tokenizer(sample['input'], return_tensors="pt").to("cuda")
model.eval()
with torch.no_grad():
    ft_completion = tokenizer.decode(model.generate(**model_input,
                                    max_new_tokens=100)[0],
                                     skip_special_tokens=True)

# prompt the base model
result = pg.Completion.create(
   model="Llama-2-7B",
   prompt=sample['input']
)
base_completion = result['choices'][0]['text']

print('Dialogue:')
print('--------------------------------------------------------')
print(sample['dialogue'])
print('')
print('Reference Summary')
print('--------------------------------------------------------')
print(sample['output'])
print('')
print('Base Model Summary')
print('--------------------------------------------------------')
print(base_completion.split('\n')[0])
print('')
print('Fine-Tuned Model Summary')
print('--------------------------------------------------------')
print(ft_completion.split(sample['input'])[1].split('\n')[0].split("#")[0])
# Out:
# Dialogue:
# --------------------------------------------------------
# Lisa: I have to clean the house.
# Bob: Yes, it's very dirty.
# Lisa: You can help me.
# Bob: Why me?
# Lisa: Because you helped make it dirty.
# Bob: What do you want me to do?
# Lisa: I want you to clean the bathroom.
# Bob: Oh, that's easy.
# Lisa: Clean the sink, the tub, the counter, and the toilet.
# Bob: That's a lot of work.
# Lisa: Tell me when you finish.
# Bob: I don't think so. You'll just give me more work.
#
# Reference Summary
# --------------------------------------------------------
# Bob is going to help Lisa clean the house, he will clean the bathroom.
#
# Base Model Summary
# --------------------------------------------------------
# Lisa: I have to clean the house.
#
# Fine-Tuned Model Summary
# --------------------------------------------------------
